# %% [markdown]
# # US Golf Course Information Kiosk
#
# Detailed information on golf courses with green fees range and tees, this complete golf courses database has 15,606 records across 7,891 cities over 53 states in the United States. Each record is comprised of address, street, phone number, zip code, hole, architect, year built, public/private, guest policy, credit card, golf season, range, rental club, pro in house, metal spikes okay, weekday, weekend, tee time welcomed, rental cart available, championship par/yards/slope/USGA, middle par/yards/slope/USGA and forward par/yards/slope/USGA
#
# https://www.usabledatabases.com/database/golf-courses-in-us/

# %% [markdown]
# ## Step 1:  Clean and transform the input dataset

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json
from sqlalchemy import create_engine
from config import db_connection

# Import API key
from config import gkey

# CSV files
course = "data/course.csv"
city = "data/city.csv"
state = "data/state.csv"

# Read the golf course dataset
input_csv = pd.read_csv("data/course.csv", delimiter=',', skipinitialspace=True)
input_csv.shape
# Out:
# (15606, 34)

# %%
# Create the data frame - golf courses
course_df = pd.read_csv(course, delimiter=',', skipinitialspace=True)

# Add columns for longitude and latitude
course_df["lng"] = ""
course_df["lat"] = ""

golf_courses = course_df.rename(columns={"id": "course_id", 
                                        "title": "course"})
golf_courses
# Out:
#        course_id  city_id                             course  \
# 0              1        1    Albertville Golf & Country Club
# 1              2        1            A. J. Jolly Golf Course
# 2              3        2          Willow Point Country Club
# 3              4        3                  Alpine Bay Resort
# 4              5        4                   Maple Hills Golf
# ...          ...      ...                                ...
# 15601      15750     8219         Legion Town & Country Club
# 15602      15751     8220            Cottonwood Country Club
# 15603      15752     8221            Cedar Pines Golf Course
# 15604      15753     8222                Wheatland Golf Club
# 15605      15754     8223  Green Hills Municipal Golf Course
#
#                      street                        address  zip_code  \
# 0           Country Club Rd     Albertville, Alabama 35950   35950.0
# 1          5350 S US Hwy 27     Alexandria, Kentucky 41001   41001.0
# 2      3054 Willow Point Rd  Alexander City, Alabama 35010   35010.0
# 3           9855 Renfroe Rd          Alpine, Alabama 35014   35014.0
# 4                    Hwy 75         Altoona, Alabama 35952   35952.0
# ...                     ...                            ...       ...
# 15601        141 Airport Rd     Thermopolis, Wyoming 82443   82443.0
# 15602               15th St      Torrington, Wyoming 82240   82240.0
# 15603        2579 N Hwy 116           Upton, Wyoming 82730   82730.0
# 15604           1253 E Cole       Wheatland, Wyoming 82201   82201.0
# 15605       1455 Airport Rd         Worland, Wyoming 82401   82401.0
#
#                 phone  hole                architect year_built  ...  \
# 0      (256) 878-4403  18.0              Leon Howard       1966  ...
# 1      (606) 635-2106  18.0                      NaN       1962  ...
# 2      (256) 234-2572  18.0          Thomas H. Nicol       1961  ...
# 3      (256) 268-2920  18.0  Robert Trent Jones, Sr.       1972  ...
# 4      (205) 466-7600   9.0             Bill Ellison       1975  ...
# ...               ...   ...                      ...        ...  ...
# 15601  (307) 864-5294   9.0                Don Brunk       1962  ...
# 15602  (307) 532-3868  18.0                      NaN        NaN  ...
# 15603  (307) 468-2847   9.0                      NaN       1984  ...
# 15604  (307) 322-3675   9.0                      NaN       1960  ...
# 15605  (307) 347-8972  18.0          Local Designers       1961  ...
#
#       middle_par middle_yards middle_slope middle_usga forward_par  \
# 0             72         6068          117       68.00          72
# 1             71         5942          115       67.60          75
# 2             72         6631          135       72.20          73
# 3             72         6518          126       69.90          72
# 4             31         1800          NaN         NaN          31
# ...          ...          ...          ...         ...         ...
# 15601         35         2966          111       33.90          37
# 15602         72         6298          112       67.70          73
# 15603         36         3198          NaN         NaN          38
# 15604         36         3064          119       33.95          36
# 15605         72         6052          113       67.50          73
#
#       forward_yards forward_slope forward_usga lng lat
# 0              5196           NaN          NaN
# 1              5418           118        70.30
# 2              5373           120        70.70
# 3              5518           120        69.80
# 4              1800           NaN          NaN
# ...             ...           ...          ...  ..  ..
# 15601          2836           111        35.00
# 15602          5344           112        69.20
# 15603          2521           NaN          NaN
# 15604          2557           116        34.25
# 15605          5104            95        65.50
#
# [15606 rows x 36 columns]

# %%
# Checking for duplicate rows in golf courses
duplicateRow = golf_courses[golf_courses.duplicated()]
duplicateRow
# Out:
# Empty DataFrame
# Columns: [course_id, city_id, course, street, address, zip_code, phone, hole, architect, year_built, public_private, guest_policy, credit_card, golf_season, range, rental_club, pro_in_House, metal_spikes_okay, weekday, weekend, tee_time_welcomed, rental_cart_available, championship_par, championship_yards, championship_slope, championship_usga, middle_par, middle_yards, middle_slope, middle_usga, forward_par, forward_yards, forward_slope, forward_usga, lng, lat]
# Index: []
#
# [0 rows x 36 columns]

# %%
# Create the data frame - golf cities
city_df = pd.read_csv(city, delimiter=',', skipinitialspace=True)

golf_cities = city_df.rename(columns={"id": "city_id", 
                                      "title": "city", 
                                      "count": "city_count", 
                                      "slug": "city_slug"})
golf_cities
# Out:
#       city_id  state_id            city  city_count      city_slug
# 0           1         1     Albertville           2    albertville
# 1           2         1  Alexander City           1  alexandercity
# 2           3         1          Alpine           1         alpine
# 3           4         1         Altoona           1        altoona
# 4           5         1       Andalusia           2      andalusia
# ...       ...       ...             ...         ...            ...
# 7886     8219        53     Thermopolis           1    thermopolis
# 7887     8220        53      Torrington           1     torrington
# 7888     8221        53           Upton           1          upton
# 7889     8222        53       Wheatland           1      wheatland
# 7890     8223        53         Worland           1        worland
#
# [7891 rows x 5 columns]

# %%
# Checking for duplicate rows in golf cities
duplicateRow = golf_cities[golf_cities.duplicated()]
duplicateRow
# Out:
# Empty DataFrame
# Columns: [city_id, state_id, city, city_count, city_slug]
# Index: []

# %%
# Create the data frame - golf states
state_df = pd.read_csv(state, delimiter=',', skipinitialspace=True)

golf_states = state_df.rename(columns={"id": "state_id", 
                                       "title": "state", 
                                       "count": "state_count", 
                                       "slug": "state_slug"})
golf_states
# Out:
#     state_id                 state  state_count          state_slug
# 0          1               Alabama          272             alabama
# 1          2                Alaska           16              alaska
# 2          3               Arizona          308             arizona
# 3          4              Arkansas          179            arkansas
# 4          5            California          976          california
# 5          6              Colorado          223            colorado
# 6          7           Connecticut          177         connecticut
# 7          8              Delaware           39            delaware
# 8          9  District of Columbia            6  districtofcolumbia
# 9         10               Florida         1094             florida
# 10        11               Georgia          432             georgia
# 11        12                Hawaii           84              hawaii
# 12        13                 Idaho           92               idaho
# 13        14              Illinois          714            illinois
# 14        15               Indiana          459             indiana
# 15        16                  Iowa          380                iowa
# 16        17                Kansas          222              kansas
# 17        18              Kentucky          279            kentucky
# 18        19             Louisiana          156           louisiana
# 19        20                 Maine          117               maine
# 20        21              Maryland           86            maryland
# 21        22         Massachusetts          340       massachusetts
# 22        23              Michigan          933            michigan
# 23        24             Minnesota          484           minnesota
# 24        25           Mississippi          162         mississippi
# 25        26              Missouri          319            missouri
# 26        27               Montana           86             montana
# 27        28              Nebraska          180            nebraska
# 28        29                Nevada           58              nevada
# 29        30         New Hampshire           99        newhampshire
# 30        31            New Jersey          290           newjersey
# 31        32            New Mexico           50           newmexico
# 32        33              New York          596             newyork
# 33        34        North Carolina          569       northcarolina
# 34        35          North Dakota           90         northdakota
# 35        36                  Ohio          772                ohio
# 36        37              Oklahoma          188            oklahoma
# 37        38                Oregon          201              oregon
# 38        39          Pennsylvania          732        pennsylvania
# 39        40           Puerto Rico           17          puertorico
# 40        41          Rhode Island           50         rhodeisland
# 41        42        South Carolina          365       southcarolina
# 42        43          South Dakota           88         southdakota
# 43        44             Tennessee          294           tennessee
# 44        45                 Texas          849               texas
# 45        46                  Utah          111                utah
# 46        47               Vermont           65             vermont
# 47        48              Virginia          347            virginia
# 48        49        Virgin Islands            4       virginislands
# 49        50            Washington          289          washington
# 50        51         West Virginia          110        westvirginia
# 51        52             Wisconsin          509           wisconsin
# 52        53               Wyoming           48             wyoming

# %%
# Checking for duplicate rows in golf states
duplicateRow = golf_states[golf_states.duplicated()]
duplicateRow
# Out:
# Empty DataFrame
# Columns: [state_id, state, state_count, state_slug]
# Index: []

# %% [markdown]
# ### Merge the data frames to create one complete dataset

# %%
# Merge the city and state dataframes using a left join
city_state_df = pd.merge(golf_cities, golf_states, on="state_id", how="left")
city_state_df
# Out:
#       city_id  state_id            city  city_count      city_slug    state  \
# 0           1         1     Albertville           2    albertville  Alabama
# 1           2         1  Alexander City           1  alexandercity  Alabama
# 2           3         1          Alpine           1         alpine  Alabama
# 3           4         1         Altoona           1        altoona  Alabama
# 4           5         1       Andalusia           2      andalusia  Alabama
# ...       ...       ...             ...         ...            ...      ...
# 7886     8219        53     Thermopolis           1    thermopolis  Wyoming
# 7887     8220        53      Torrington           1     torrington  Wyoming
# 7888     8221        53           Upton           1          upton  Wyoming
# 7889     8222        53       Wheatland           1      wheatland  Wyoming
# 7890     8223        53         Worland           1        worland  Wyoming
#
#       state_count state_slug
# 0             272    alabama
# 1             272    alabama
# 2             272    alabama
# 3             272    alabama
# 4             272    alabama
# ...           ...        ...
# 7886           48    wyoming
# 7887           48    wyoming
# 7888           48    wyoming
# 7889           48    wyoming
# 7890           48    wyoming
#
# [7891 rows x 8 columns]

# %%
# Merge the city_state dataframe with the golf course dataframe using a left join
golf_courses = pd.merge(golf_courses, city_state_df, on="city_id" ,how="left")
golf_courses
# Out:
#        course_id  city_id                             course  \
# 0              1        1    Albertville Golf & Country Club
# 1              2        1            A. J. Jolly Golf Course
# 2              3        2          Willow Point Country Club
# 3              4        3                  Alpine Bay Resort
# 4              5        4                   Maple Hills Golf
# ...          ...      ...                                ...
# 15601      15750     8219         Legion Town & Country Club
# 15602      15751     8220            Cottonwood Country Club
# 15603      15752     8221            Cedar Pines Golf Course
# 15604      15753     8222                Wheatland Golf Club
# 15605      15754     8223  Green Hills Municipal Golf Course
#
#                      street                        address  zip_code  \
# 0           Country Club Rd     Albertville, Alabama 35950   35950.0
# 1          5350 S US Hwy 27     Alexandria, Kentucky 41001   41001.0
# 2      3054 Willow Point Rd  Alexander City, Alabama 35010   35010.0
# 3           9855 Renfroe Rd          Alpine, Alabama 35014   35014.0
# 4                    Hwy 75         Altoona, Alabama 35952   35952.0
# ...                     ...                            ...       ...
# 15601        141 Airport Rd     Thermopolis, Wyoming 82443   82443.0
# 15602               15th St      Torrington, Wyoming 82240   82240.0
# 15603        2579 N Hwy 116           Upton, Wyoming 82730   82730.0
# 15604           1253 E Cole       Wheatland, Wyoming 82201   82201.0
# 15605       1455 Airport Rd         Worland, Wyoming 82401   82401.0
#
#                 phone  hole                architect year_built  ...  \
# 0      (256) 878-4403  18.0              Leon Howard       1966  ...
# 1      (606) 635-2106  18.0                      NaN       1962  ...
# 2      (256) 234-2572  18.0          Thomas H. Nicol       1961  ...
# 3      (256) 268-2920  18.0  Robert Trent Jones, Sr.       1972  ...
# 4      (205) 466-7600   9.0             Bill Ellison       1975  ...
# ...               ...   ...                      ...        ...  ...
# 15601  (307) 864-5294   9.0                Don Brunk       1962  ...
# 15602  (307) 532-3868  18.0                      NaN        NaN  ...
# 15603  (307) 468-2847   9.0                      NaN       1984  ...
# 15604  (307) 322-3675   9.0                      NaN       1960  ...
# 15605  (307) 347-8972  18.0          Local Designers       1961  ...
#
#       forward_usga lng lat state_id            city city_count      city_slug  \
# 0              NaN                1     Albertville          2    albertville
# 1            70.30                1     Albertville          2    albertville
# 2            70.70                1  Alexander City          1  alexandercity
# 3            69.80                1          Alpine          1         alpine
# 4              NaN                1         Altoona          1        altoona
# ...            ...  ..  ..      ...             ...        ...            ...
# 15601        35.00               53     Thermopolis          1    thermopolis
# 15602        69.20               53      Torrington          1     torrington
# 15603          NaN               53           Upton          1          upton
# 15604        34.25               53       Wheatland          1      wheatland
# 15605        65.50               53         Worland          1        worland
#
#          state state_count state_slug
# 0      Alabama         272    alabama
# 1      Alabama         272    alabama
# 2      Alabama         272    alabama
# 3      Alabama         272    alabama
# 4      Alabama         272    alabama
# ...        ...         ...        ...
# 15601  Wyoming          48    wyoming
# 15602  Wyoming          48    wyoming
# 15603  Wyoming          48    wyoming
# 15604  Wyoming          48    wyoming
# 15605  Wyoming          48    wyoming
#
# [15606 rows x 43 columns]

# %%
# Select the golf course columns needed for course longitude, latitude
golf_course_df = golf_courses[["course_id", 
                               "course", 
                               "city", 
                               "state", 
                               "street", 
                               "zip_code", 
                               "lng", 
                               "lat", 
                               "hole"]]
                     
# Display the new dataframe
golf_course_df
# Out:
#        course_id                             course            city    state  \
# 0              1    Albertville Golf & Country Club     Albertville  Alabama
# 1              2            A. J. Jolly Golf Course     Albertville  Alabama
# 2              3          Willow Point Country Club  Alexander City  Alabama
# 3              4                  Alpine Bay Resort          Alpine  Alabama
# 4              5                   Maple Hills Golf         Altoona  Alabama
# ...          ...                                ...             ...      ...
# 15601      15750         Legion Town & Country Club     Thermopolis  Wyoming
# 15602      15751            Cottonwood Country Club      Torrington  Wyoming
# 15603      15752            Cedar Pines Golf Course           Upton  Wyoming
# 15604      15753                Wheatland Golf Club       Wheatland  Wyoming
# 15605      15754  Green Hills Municipal Golf Course         Worland  Wyoming
#
#                      street  zip_code lng lat  hole
# 0           Country Club Rd   35950.0          18.0
# 1          5350 S US Hwy 27   41001.0          18.0
# 2      3054 Willow Point Rd   35010.0          18.0
# 3           9855 Renfroe Rd   35014.0          18.0
# 4                    Hwy 75   35952.0           9.0
# ...                     ...       ...  ..  ..   ...
# 15601        141 Airport Rd   82443.0           9.0
# 15602               15th St   82240.0          18.0
# 15603        2579 N Hwy 116   82730.0           9.0
# 15604           1253 E Cole   82201.0           9.0
# 15605       1455 Airport Rd   82401.0          18.0
#
# [15606 rows x 9 columns]

# %%
# Select the golf course columns needed for golf kiosk - general information
course_info = golf_courses[["course_id", 
                               "phone", 
                               "hole", 
                               "architect", 
                               "year_built", 
                               "public_private", 
                               "guest_policy", 
                               "credit_card"]]
                     
# Display the new dataframe
course_info
# Out:
#        course_id           phone  hole                architect year_built  \
# 0              1  (256) 878-4403  18.0              Leon Howard       1966
# 1              2  (606) 635-2106  18.0                      NaN       1962
# 2              3  (256) 234-2572  18.0          Thomas H. Nicol       1961
# 3              4  (256) 268-2920  18.0  Robert Trent Jones, Sr.       1972
# 4              5  (205) 466-7600   9.0             Bill Ellison       1975
# ...          ...             ...   ...                      ...        ...
# 15601      15750  (307) 864-5294   9.0                Don Brunk       1962
# 15602      15751  (307) 532-3868  18.0                      NaN        NaN
# 15603      15752  (307) 468-2847   9.0                      NaN       1984
# 15604      15753  (307) 322-3675   9.0                      NaN       1960
# 15605      15754  (307) 347-8972  18.0          Local Designers       1961
#
#       public_private guest_policy                                credit_card
# 0            Private       Closed                                       None
# 1             Public         Open                  VISA, MasterCard Welcomed
# 2            Private       Closed            VISA, MasterCard, Amex Accepted
# 3             Resort         Open  VISA, MasterCard, Amex, Discover Accepted
# 4             Public         Open                                       None
# ...              ...          ...                                        ...
# 15601         Public         Open            VISA, MasterCard, Amex Welcomed
# 15602         Public         Open                  VISA, MasterCard Welcomed
# 15603   Semi-Private         Open                                       None
# 15604         Public         Open  VISA, MasterCard, Amex, Discover Welcomed
# 15605         Public         Open                  VISA, MasterCard Welcomed
#
# [15606 rows x 8 columns]

# %%
# Select the golf course columns needed for golf kiosk - course details
course_details = golf_courses[["course_id", 
                               "golf_season",
                               "range", 
                               "rental_club", 
                               "pro_in_House", 
                               "metal_spikes_okay", 
                               "weekday", 
                               "weekend", 
                               "tee_time_welcomed", 
                               "rental_cart_available"]]
                     
# Display the new dataframe
course_details
# Out:
#        course_id               golf_season range rental_club pro_in_House  \
# 0              1                year round    No          No           No
# 1              2                year round    No         Yes          Yes
# 2              3                year round   Yes         Yes          Yes
# 3              4                year round   Yes         Yes          Yes
# 4              5                year round    No          No          Yes
# ...          ...                       ...   ...         ...          ...
# 15601      15750  Open: 4/01 Closed: 11/01   Yes         Yes          Yes
# 15602      15751  Open: 4/01 Closed: 11/01   Yes         Yes           No
# 15603      15752  Open: 4/01 Closed: 11/01   Yes         Yes           No
# 15604      15753  Open: 4/01 Closed: 11/01   Yes         Yes           No
# 15605      15754  Open: 4/01 Closed: 10/31   Yes         Yes          Yes
#
#       metal_spikes_okay weekday weekend tee_time_welcomed  \
# 0                   Yes       $       $                No
# 1                   Yes       $       $               Yes
# 2                   Yes       $       $               Yes
# 3                    No       $       $               Yes
# 4                   Yes       $       $                No
# ...                 ...     ...     ...               ...
# 15601                No       $       $               Yes
# 15602                No       $       $                No
# 15603               Yes       $       $                No
# 15604                No       $       $               Yes
# 15605                No       $       $               Yes
#
#       rental_cart_available
# 0                        No
# 1                       Yes
# 2                       Yes
# 3                       Yes
# 4                        No
# ...                     ...
# 15601                   Yes
# 15602                   Yes
# 15603                   Yes
# 15604                   Yes
# 15605                   Yes
#
# [15606 rows x 10 columns]

# %%
# Select the golf course columns needed for golf kiosk - championship tees
championship_tees = golf_courses[["course_id", 
                            "championship_par", 
                            "championship_yards", 
                            "championship_slope", 
                            "championship_usga"]]
                     
# Display the new dataframe
championship_tees
# Out:
#        course_id championship_par championship_yards championship_slope  \
# 0              1               72               6332                118
# 1              2               71               6219                118
# 2              3               72               7084                137
# 3              4               72               6900                129
# 4              5              NaN                NaN                NaN
# ...          ...              ...                ...                ...
# 15601      15750              NaN                NaN                NaN
# 15602      15751              NaN                NaN                NaN
# 15603      15752              NaN                NaN                NaN
# 15604      15753              NaN                NaN                NaN
# 15605      15754               72               6444                113
#
#       championship_usga
# 0                 68.80
# 1                 69.30
# 2                 74.60
# 3                 70.90
# 4                   NaN
# ...                 ...
# 15601               NaN
# 15602               NaN
# 15603               NaN
# 15604               NaN
# 15605             69.30
#
# [15606 rows x 5 columns]

# %%
# Select the golf course columns needed for golf kiosk - middle tees
middle_tees = golf_courses[["course_id", 
                                  "middle_par", 
                                  "middle_yards", 
                                  "middle_slope", 
                                  "middle_usga"]]
                     
# Display the new dataframe
middle_tees
# Out:
#        course_id middle_par middle_yards middle_slope middle_usga
# 0              1         72         6068          117       68.00
# 1              2         71         5942          115       67.60
# 2              3         72         6631          135       72.20
# 3              4         72         6518          126       69.90
# 4              5         31         1800          NaN         NaN
# ...          ...        ...          ...          ...         ...
# 15601      15750         35         2966          111       33.90
# 15602      15751         72         6298          112       67.70
# 15603      15752         36         3198          NaN         NaN
# 15604      15753         36         3064          119       33.95
# 15605      15754         72         6052          113       67.50
#
# [15606 rows x 5 columns]

# %%
# Select the golf course columns needed for golf kiosk - forward tees
forward_tees = golf_courses[["course_id", 
                                  "forward_par", 
                                  "forward_yards", 
                                  "forward_slope", 
                                  "forward_usga"]]
                     
# Display the new dataframe
forward_tees
# Out:
#        course_id forward_par forward_yards forward_slope forward_usga
# 0              1          72          5196           NaN          NaN
# 1              2          75          5418           118        70.30
# 2              3          73          5373           120        70.70
# 3              4          72          5518           120        69.80
# 4              5          31          1800           NaN          NaN
# ...          ...         ...           ...           ...          ...
# 15601      15750          37          2836           111        35.00
# 15602      15751          73          5344           112        69.20
# 15603      15752          38          2521           NaN          NaN
# 15604      15753          36          2557           116        34.25
# 15605      15754          73          5104            95        65.50
#
# [15606 rows x 5 columns]

# %%
# Create subst of golf courses
course_subset = golf_course_df[((golf_course_df["zip_code"] >= 55001) & (golf_course_df["zip_code"] <= 56763))]
course_subset
# Out:
#       course_id                         course         city      state  \
# 7584       7671  Heart of the Valley Golf Club          Ada  Minnesota
# 7585       7672       Cedar River Country Club        Adams  Minnesota
# 7586       7673             Adrian Golf Course       Adrian  Minnesota
# 7587       7674               Albany Golf Club       Albany  Minnesota
# 7588       7675           Albert Lea Golf Club   Albert Lea  Minnesota
# ...         ...                            ...          ...        ...
# 8063       8155        Prairie View Golf Links  Worthington  Minnesota
# 8064       8156       Worthington Country Club  Worthington  Minnesota
# 8065       8157     Greenwood Golf Links, Inc.      Wyoming  Minnesota
# 8066       8158     Fairway Shores Golf Course    Zimmerman  Minnesota
# 8067       8159             Zumbrota Golf Club     Zumbrota  Minnesota
#
#                     street  zip_code lng lat  hole
# 7584      SE Corner of Ada   56510.0           9.0
# 7585              Hwy 56 W   55909.0          18.0
# 7586              Hwy 91 S   56110.0           9.0
# 7587         500 Church St   56307.0          18.0
# 7588  1701 Country Club Rd   56007.0          18.0
# ...                    ...       ...  ..  ..   ...
# 8063            Hwy 266 No   56187.0          18.0
# 8064       1414 Liberty Dr   56187.0          18.0
# 8065    4520 E Viking Blvd   55092.0          18.0
# 8066        28340 131St St   55398.0           9.0
# 8067        Sugarloaf Pkwy   55992.0           9.0
#
# [484 rows x 9 columns]

# %%
# Getting the longitude and latitude for each golf course
count = 0

# Use the street, city, state to get lng and lat
for index, row in course_subset.iterrows():
    # get street, city, state from golf_course_df
    street = row["street"]
    city = row["city"]
    state = row["state"]

    # Getting lat/lng
    query_address_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={street},+{city},+{state}&key={gkey}"
    # print(f"url = {query_address_url}")

    response = requests.get(query_address_url).json()
    # print(f"response = {response}")
    
    count = count + 1
    # print(f"#{count} - index = {index}")
    
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        course_subset.loc[index, "lat"] = response["results"][0]["geometry"]["location"]["lat"]
        course_subset.loc[index, "lng"] = response["results"][0]["geometry"]["location"]["lng"]
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# C:\Users\Public\anaconda3\envs\NewPythonData\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Missing field/result... skipping.

# %%
# Preview course subset
course_subset
# Out:
#       course_id                         course         city      state  \
# 7584       7671  Heart of the Valley Golf Club          Ada  Minnesota
# 7585       7672       Cedar River Country Club        Adams  Minnesota
# 7586       7673             Adrian Golf Course       Adrian  Minnesota
# 7587       7674               Albany Golf Club       Albany  Minnesota
# 7588       7675           Albert Lea Golf Club   Albert Lea  Minnesota
# ...         ...                            ...          ...        ...
# 8063       8155        Prairie View Golf Links  Worthington  Minnesota
# 8064       8156       Worthington Country Club  Worthington  Minnesota
# 8065       8157     Greenwood Golf Links, Inc.      Wyoming  Minnesota
# 8066       8158     Fairway Shores Golf Course    Zimmerman  Minnesota
# 8067       8159             Zumbrota Golf Club     Zumbrota  Minnesota
#
#                     street  zip_code      lng      lat  hole
# 7584      SE Corner of Ada   56510.0 -96.5153  47.2997   9.0
# 7585              Hwy 56 W   55909.0 -92.7193  43.5654  18.0
# 7586              Hwy 91 S   56110.0 -95.9331   43.635   9.0
# 7587         500 Church St   56307.0 -94.5703  45.6291  18.0
# 7588  1701 Country Club Rd   56007.0 -93.3907  43.6706  18.0
# ...                    ...       ...      ...      ...   ...
# 8063            Hwy 266 No   56187.0 -95.7137  43.7012  18.0
# 8064       1414 Liberty Dr   56187.0 -95.6228  43.6255  18.0
# 8065    4520 E Viking Blvd   55092.0 -93.0147  45.3406  18.0
# 8066        28340 131St St   55398.0 -93.6016  45.4848   9.0
# 8067        Sugarloaf Pkwy   55992.0 -92.6779   44.308   9.0
#
# [484 rows x 9 columns]

# %%
# Export the golf course data into a csv
course_subset.to_csv("results/course_subset.csv", index=False, header=True)
